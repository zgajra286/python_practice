# %% [markdown]
# <a href="https://colab.research.google.com/github/zgajra286/python_practice/blob/master/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nums = [8, 1, 6, 4]

mx = nums[0]

for n in nums:
    if n > mx:
        mx = n

print(mx)
# Out:
# 8

# %%
# Print numbers from 20 down to 2, skipping all odd numbers.

# %%
i = 20
while i >= 2:
  print(i)
  i = i-2
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2

# %%
i = 0
while i>= 5:
      print(i)
      i = i+7

# %%
num = input("Enter number = ")
i = 1

while i<=5:
  print(num*i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# ...

# %%
num=7
count = 1
while count<=5:
  print(num)
  count = count+1
  num = num+7
# Out:
# 7
# 14
# 21
# 28
# 35

# %%
num = int(input("Enter a number : "))
end = int(input("Enter the range upto which you want the table : "))
count= 1
while count<=end:
  total = num * count
  print(num ,"*" ,count ,"=" ,total)
  count = count +1
# Out:
# Enter a number : 7
# Enter the range upto which you want the table : 15
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
# 7 * 11 = 77
# 7 * 12 = 84
# 7 * 13 = 91
# 7 * 14 = 98
# 7 * 15 = 105

# %%
# Create tables from 1 to 10 for any number using for loop.
num = int(input("Enter a number : "))
for i in range(1,11):
   answer =num*i
   print(num, "*" , i ,"=", answer)
# Out:
# Enter a number : 15
# 15 * 1 = 15
# 15 * 2 = 30
# 15 * 3 = 45
# 15 * 4 = 60
# 15 * 5 = 75
# 15 * 6 = 90
# 15 * 7 = 105
# 15 * 8 = 120
# 15 * 9 = 135
# 15 * 10 = 150

# %%
# Create full tables from 1 to 10 for numbers 1 to 10 (nested loops).
for num in range(1,10):

  for table in range(1,10):
    print(num)
    answer = table * num
    print(num , "*",table ,"=", answer)
print(num)
# Out:
# 1
# 1 * 1 = 1
# 1
# 1 * 2 = 2
# 1
# 1 * 3 = 3
# 1
# 1 * 4 = 4
# 1
# 1 * 5 = 5
# 1
# 1 * 6 = 6
# 1
# 1 * 7 = 7
# 1
# 1 * 8 = 8
# 1
# 1 * 9 = 9
# 2
# 2 * 1 = 2
# 2
# 2 * 2 = 4
# 2
# 2 * 3 = 6
# 2
# 2 * 4 = 8
# 2
# 2 * 5 = 10
# 2
# 2 * 6 = 12
# 2
# 2 * 7 = 14
# 2
# 2 * 8 = 16
# 2
# 2 * 9 = 18
# 3
# 3 * 1 = 3
# 3
# 3 * 2 = 6
# 3
# 3 * 3 = 9
# 3
# 3 * 4 = 12
# 3
# 3 * 5 = 15
# 3
# 3 * 6 = 18
# 3
# 3 * 7 = 21
# 3
# 3 * 8 = 24
# 3
# 3 * 9 = 27
# 4
# 4 * 1 = 4
# 4
# 4 * 2 = 8
# 4
# 4 * 3 = 12
# 4
# 4 * 4 = 16
# 4
# 4 * 5 = 20
# 4
# 4 * 6 = 24
# 4
# 4 * 7 = 28
# 4
# 4 * 8 = 32
# 4
# 4 * 9 = 36
# 5
# 5 * 1 = 5
# 5
# 5 * 2 = 10
# 5
# 5 * 3 = 15
# 5
# 5 * 4 = 20
# 5
# 5 * 5 = 25
# 5
# 5 * 6 = 30
# 5
# 5 * 7 = 35
# 5
# 5 * 8 = 40
# 5
# 5 * 9 = 45
# 6
# 6 * 1 = 6
# 6
# 6 * 2 = 12
# 6
# 6 * 3 = 18
# 6
# 6 * 4 = 24
# 6
# 6 * 5 = 30
# 6
# 6 * 6 = 36
# 6
# 6 * 7 = 42
# 6
# 6 * 8 = 48
# 6
# 6 * 9 = 54
# 7
# 7 * 1 = 7
# 7
# 7 * 2 = 14
# 7
# 7 * 3 = 21
# 7
# 7 * 4 = 28
# 7
# 7 * 5 = 35
# 7
# 7 * 6 = 42
# ...

# %%
# Print only the tables of 2, 4, and 6, from 1 to 5.
for even in range(2,7,2):
  print("Table for : " , even)
  for num in range(1,6):
      answer = even * num
      print(even ,"*" , num,"=",answer)
# Out:
# Table for :  2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# Table for :  4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# Table for :  6
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30

# %%
# Write a program to greet all the person names stored in a list ‘l’ and which starts
# with S.
# l = ["Harry", "Soham", "Sachin", "Rahul"]
l = ["Harry", "Soham", "Sachin", "Rahul"]
for name in l:
    if name[0] == 'S':
        print("Hello",name)
# Out:
# Hello Soham
# Hello Sachin

# %%
n = int(input("Check whether the number is prime or not: "))
for num in range(2,10):
  if n % num == 0:
   print("not a prime number")
   break

  else:
    print("Entered number is a prime number")
    break
# Out:
# Check whether the number is prime or not: 12
# not a prime number

# %%
n = int(input("Check whether the number is prime or not: "))

if n <= 1:
    print("Not a prime number")
else:
    for num in range(2, n):
        if n % num == 0:
            print("Not a prime number")
            break
    else:
        print("Entered number is a prime number")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1875/3555800134.py in <cell line: 0>()
# ----> 1 n = int(input("Check whether the number is prime or not: "))
#       2
#       3 if n <= 1:
#       4     print("Not a prime number")
#       5 else:
#
# TypeError: 'int' object is not callable

# %%
def test():
    a = 10
    print(a)
test()
# Out:
# 10

# %%
def add(a, b):
    print(a + b)

print(add(2,3))
# Out:
# 5
# None

# %%
a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
c=int(input("Enter a number: "))
def greatest_number(a,b,c):

  if (a>b)and (a>c):
        print(f"{a} is the greatest number")
  elif (b>a)and (b>c):
        print(f"{b} is the greatest number")
  else:
        print(f"{c} is the greatest number")

greatest_number(a,b,c)
# Out:
# Enter a number: 5
# Enter a number: 6
# Enter a number: 7
# 7 is the greatest number

# %%
celcius= int(input("Enter the temperature in celcius which will be converted to fahrenheit = "))
def celcius_to_fahrenheit(celcius):
  fahrenheit =(celcius* 1.8)  + 32
  return(fahrenheit)

celcius_to_fahrenheit(celcius)
# Out:
# Enter the temperature in celcius which will be converted to fahrenheit = 0
# 32.0

# %%
def factorial(n):
  if n==0 or n==1:
    return 1
  return n*factorial(n-1)




print(factorial(5))
# Out:
# 120

# %%
def sum(n):
  if n==0:
    return 0
  return n+sum(n-1)
print(sum(5))
# Out:
# 15

# %%
def pattern(n):
  if n==0 :
    return
  print(f"*"*n)
  pattern(n-1)
pattern(3)
# Out:
# ***
# **
# *

# %%
num=0
n=int(input("Enter the number for which you want to print the table: "))
end = int(input("Enter the range upto which you want the table : "))

def multiplication_table(n,end):
       for i in range(1,end+1):

         num=n*i
         print(n,"*",i , "=",num)
       print("Table printed")



multiplication_table(n,end)
# Out:
# Enter the number for which you want to print the table: 5
# Enter the range upto which you want the table : 15
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
# 5 * 11 = 55
# 5 * 12 = 60
# 5 * 13 = 65
# 5 * 14 = 70
# 5 * 15 = 75
# Table printed

# %%
# water , snake and gun

import random
user_input= input("Enter your choice : ").lower()
# print(type(user_input))
user = {"snake":-1 , "water":0, "gun":1}
user_move = user[user_input]

reverse_user = {-1:"snake", 0:"water", 1:"gun"}
computer_move = random.choice(list(reverse_user.keys()))
computer_value=reverse_user[computer_move]
print(computer_value)

if user_move == computer_move:
  print("Draw as you both selected : ",user_input)
else:
  if (user_move == 0 and computer_move ==1):
       print("You won as you choose",user_input," which beats what computer chose which is ",computer_value)
  elif (user_move == 1 and computer_move ==-1):
       print("You won as you choose",user_input," which beats what computer chose which is ",computer_value)
  elif (user_move == -1 and computer_move == 0):
       print("You won as you choose",user_input," which beats what computer chose which is ",computer_value)
  elif (user_move == -1 and computer_move == 1):
       print("You loose as you choose",user_input," which looses to what computer chose which is ",computer_value)
  elif (user_move == 1 and computer_move == 0):
       print("You loose as you choose",user_input," which looses to what computer chose which is ",computer_value)
  elif (user_move == 0 and computer_move == -1):
       print("You loose as you choose",user_input," which looses to what computer chose which is ",computer_value)
  else:
    (print("something went wrong"))
# Out:
# Enter your choice : gun
# snake
# You won as you choose gun  which beats what computer chose which is  snake

# %%
import random
def game():
  random_number = random.randint(1,50)
  print(random_number)
game()

write f(open)
# Out:
# 8

# %%
class Car:
    brand = "Toyota"   # class attribute

    def __init__(self, model):
        self.model = model   # instance attribute

    def show(self):          # method
        print(self.brand, self.model)

c1 = Car("Fortuner")
c2 = Car("Innova")

print(c1)
c2.show()
# Out:
# ...
# Toyota Innova

# %%
class Student:
    def __init__(self, name):
        self.name = name   # instance attribute

s1 = Student("Zeel")
s2 = Student("Raj")
print(s1.name)
# Out:
# Zeel
